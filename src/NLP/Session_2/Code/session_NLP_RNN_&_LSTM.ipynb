# %% [markdown]
# ## Load and handle Dataset

# %%
import csv
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, LSTM, Dropout, Activation, Embedding, Bidirectional,SimpleRNN
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))

# %%
vocab_size = 5000
embedding_dim = 64
max_length = 200
oov_tok = '<OOV>' #  Out of Vocabulary
training_portion = 0.8

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Lenovo\Desktop\DEPI(R_2)\ML_git\GIZ4_AIS2_S1_Ml\src\NLP\Session_2\Code\bbc-text.csv')

# %%
df
# Out:
#            category                                               text
# 0              tech  tv future in the hands of viewers with home th...
# 1          business  worldcom boss  left books alone  former worldc...
# 2             sport  tigers wary of farrell  gamble  leicester say ...
# 3             sport  yeading face newcastle in fa cup premiership s...
# 4     entertainment  ocean s twelve raids box office ocean s twelve...
# ...             ...                                                ...
# 2220       business  cars pull down us retail figures us retail sal...
# 2221       politics  kilroy unveils immigration policy ex-chatshow ...
# 2222  entertainment  rem announce new glasgow concert us band rem h...
# 2223       politics  how political squabbles snowball it s become c...
# 2224          sport  souness delight at euro progress boss graeme s...
#
# [2225 rows x 2 columns]

# %%
df['category'].value_counts()
# Out:
# category
# sport            511
# business         510
# politics         417
# tech             401
# entertainment    386
# Name: count, dtype: int64

# %%
articles = df['text'].values
labels = df['category'].values

# %%
len(labels),len(articles)
# Out:
# (2225, 2225)

# %%
labels[0],articles[0]
# Out:
# ('tech',
#  'tv future in the hands of viewers with home theatre systems  plasma high-definition tvs  and digital video recorders moving into the living room  the way people watch tv will be radically different in five years  time.  that is according to an expert panel which gathered at the annual consumer electronics show in las vegas to discuss how these new technologies will impact one of our favourite pastimes. with the us leading the trend  programmes and other content will be delivered to viewers via home networks  through cable  satellite  telecoms companies  and broadband service providers to front rooms and portable devices.  one of the most talked-about technologies of ces has been digital and personal video recorders (dvr and pvr). these set-top boxes  like the us s tivo and the uk s sky+ system  allow people to record  store  play  pause and forward wind tv programmes when they want.  essentially  the technology allows for much more personalised tv. they are also being built-in to high-definition tv sets  which are big business in japan and the us  but slower to take off in europe because of the lack of high-definition programming. not only can people forward wind through adverts  they can also forget about abiding by network and channel schedules  putting together their own a-la-carte entertainment. but some us networks and cable and satellite companies are worried about what it means for them in terms of advertising revenues as well as  brand identity  and viewer loyalty to channels. although the us leads in this technology at the moment  it is also a concern that is being raised in europe  particularly with the growing uptake of services like sky+.  what happens here today  we will see in nine months to a years  time in the uk   adam hume  the bbc broadcast s futurologist told the bbc news website. for the likes of the bbc  there are no issues of lost advertising revenue yet. it is a more pressing issue at the moment for commercial uk broadcasters  but brand loyalty is important for everyone.  we will be talking more about content brands rather than network brands   said tim hanlon  from brand communications firm starcom mediavest.  the reality is that with broadband connections  anybody can be the producer of content.  he added:  the challenge now is that it is hard to promote a programme with so much choice.   what this means  said stacey jolna  senior vice president of tv guide tv group  is that the way people find the content they want to watch has to be simplified for tv viewers. it means that networks  in us terms  or channels could take a leaf out of google s book and be the search engine of the future  instead of the scheduler to help people find what they want to watch. this kind of channel model might work for the younger ipod generation which is used to taking control of their gadgets and what they play on them. but it might not suit everyone  the panel recognised. older generations are more comfortable with familiar schedules and channel brands because they know what they are getting. they perhaps do not want so much of the choice put into their hands  mr hanlon suggested.  on the other end  you have the kids just out of diapers who are pushing buttons already - everything is possible and available to them   said mr hanlon.  ultimately  the consumer will tell the market they want.   of the 50 000 new gadgets and technologies being showcased at ces  many of them are about enhancing the tv-watching experience. high-definition tv sets are everywhere and many new models of lcd (liquid crystal display) tvs have been launched with dvr capability built into them  instead of being external boxes. one such example launched at the show is humax s 26-inch lcd tv with an 80-hour tivo dvr and dvd recorder. one of the us s biggest satellite tv companies  directtv  has even launched its own branded dvr at the show with 100-hours of recording capability  instant replay  and a search function. the set can pause and rewind tv fo ...

# %%
# split data into train and validation using sklearn
from sklearn.model_selection import train_test_split
train_articles, validation_articles, train_labels, validation_labels = train_test_split(articles, labels, test_size=0.2, random_state=42)

# %%
print('train_articles' ,len(train_articles))
print('train_labels', len(train_labels))
print('validation_articles', len(validation_articles))
print('validation_labels', len(validation_labels))
# Out:
# train_articles 1780
# train_labels 1780
# validation_articles 445
# validation_labels 445

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train_articles)
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'<OOV>': 1,
#  'the': 2,
#  'to': 3,
#  'of': 4,
#  'and': 5,
#  'a': 6,
#  'in': 7,
#  's': 8,
#  'for': 9,
#  'is': 10,
#  'that': 11,
#  'it': 12,
#  'on': 13,
#  'said': 14,
#  'was': 15,
#  'he': 16,
#  'be': 17,
#  'with': 18,
#  'has': 19,
#  'as': 20,
#  'have': 21,
#  'at': 22,
#  'by': 23,
#  'will': 24,
#  'but': 25,
#  'are': 26,
#  'i': 27,
#  'from': 28,
#  'not': 29,
#  'his': 30,
#  'they': 31,
#  'mr': 32,
#  'we': 33,
#  'this': 34,
#  'an': 35,
#  'had': 36,
#  'would': 37,
#  'which': 38,
#  'been': 39,
#  'their': 40,
#  'year': 41,
#  'more': 42,
#  'up': 43,
#  'its': 44,
#  'were': 45,
#  'also': 46,
#  'who': 47,
#  'new': 48,
#  'people': 49,
#  'one': 50,
#  'us': 51,
#  'there': 52,
#  'about': 53,
#  'after': 54,
#  'out': 55,
#  'can': 56,
#  'than': 57,
#  'all': 58,
#  'or': 59,
#  'if': 60,
#  'you': 61,
#  'could': 62,
#  'over': 63,
#  'last': 64,
#  'first': 65,
#  'when': 66,
#  't': 67,
#  'time': 68,
#  'two': 69,
#  'world': 70,
#  'some': 71,
#  'government': 72,
#  'into': 73,
#  'other': 74,
#  'now': 75,
#  'she': 76,
#  'what': 77,
#  'uk': 78,
#  'so': 79,
#  'years': 80,
#  'only': 81,
#  'against': 82,
#  'best': 83,
#  'just': 84,
#  'no': 85,
#  'them': 86,
#  'do': 87,
#  'being': 88,
#  'make': 89,
#  'told': 90,
#  'made': 91,
#  'game': 92,
#  'back': 93,
#  'get': 94,
#  'three': 95,
#  'music': 96,
#  'film': 97,
#  'like': 98,
#  'should': 99,
#  'such': 100,
#  '000': 101,
#  'very': 102,
#  'before': 103,
#  '1': 104,
#  'because': 105,
#  'her': 106,
#  'set': 107,
#  'while': 108,
#  'many': 109,
#  'next': 110,
#  'labour': 111,
#  'bbc': 112,
#  'take': 113,
#  'well': 114,
#  'added': 115,
#  'way': 116,
#  'most': 117,
#  'company': 118,
#  'market': 119,
#  'number': 120,
#  'may': 121,
#  '2': 122,
#  'any': 123,
#  'home': 124,
#  'off': 125,
#  'him': 126,
#  'my': 127,
#  'our': 128,
#  'says': 129,
#  'good': 130,
#  '2004': 131,
#  'election': 132,
#  'england': 133,
#  'down': 134,
#  'since': 135,
#  'much': 136,
#  'how': 137,
#  'party': 138,
#  'second': 139,
#  'then': 140,
#  'go': 141,
#  'going': 142,
#  'firm': 143,
#  'top': 144,
#  'games': 145,
#  'win': 146,
#  'those': 147,
#  'work': 148,
#  'still': 149,
#  'week': 150,
#  '6': 151,
#  'show': 152,
#  'public': 153,
#  'think': 154,
#  'use': 155,
#  'million': 156,
#  'high': 157,
#  'blair': 158,
#  'say': 159,
#  'won': 160,
#  'play': 161,
#  'part': 162,
#  'technology': 163,
#  'see': 164,
#  'between': 165,
#  '3': 166,
#  'mobile': 167,
#  'five': 168,
#  'under': 169,
#  'british': 170,
#  'both': 171,
#  'four': 172,
#  'players': 173,
#  'want': 174,
#  'did': 175,
#  'tv': 176,
#  'through': 177,
#  'minister': 178,
#  'used': 179,
#  'country': 180,
#  'news': 181,
#  'however': 182,
#  'european': 183,
#  'expected': 184,
#  '10': 185,
#  'even': 186,
#  'these': 187,
#  '4': 188,
#  'half': 189,
#  'old': 190,
#  'end': 191,
#  'group': 192,
#  'where': 193,
#  'six': 194,
#  '5': 195,
#  'during': 196,
#  'months': 197,
#  'day': 198,
#  'already': 199,
#  'brown': 200,
#  'm': 201,
#  'me': 202,
#  'plans': 203,
#  'come': 204,
#  'put': 205,
#  'sales': 206,
#  'former': 207,
#  'growth': 208,
#  'chief': 209,
#  'service': 210,
#  'own': 211,
#  'economy': 212,
#  '2005': 213,
#  'help': 214,
#  'too': 215,
#  'london': 216,
#  'long': 217,
#  'right': 218,
#  'britain': 219,
#  'net': 220,
#  'record': 221,
#  'don': 222,
#  'system': 223,
#  'team': 224,
#  'according': 225,
#  'money': 226,
#  'deal': 227,
#  'international': 228,
#  'month': 229,
#  'companies': 230,
#  'based': 231,
#  'digital': 232,
#  'tax': 233,
#  'including': 234,
#  'users': 235,
#  'services': 236,
#  'report': 237,
#  'need': 238,
#  'director': 239,
#  'third': 240,
#  'big': 241,
#  'economic': 242,
#  'industry': 243,
#  'software': 244,
#  'final': 245,
#  'around': 246,
#  'wales': 247,
#  'firms': 248,
#  'place': 249,
#  'howard': 250,
#  '2003': 251,
#  'called': 252,
#  'club': 253,
#  'great': 254,
#  'took': 255,
#  'europe': 256,
#  're': 257,
#  'hit': 258,
#  'business': 259,
#  '7': 260,
#  'move': 261,
#  'came': 262,
#  'another': 263,
#  'got': 264,
#  'better': 265,
#  'bank': 266,
#  'start': 267,
#  'life': 268,
#  'future': 269,
#  'radio': 270,
#  'really': 271,
#  'general': 272,
#  'phone': 273,
#  'open': 274,
#  'united': 275,
#  'spokesman': 276,
#  'law': 277,
#  'ireland': 278,
#  'france': 279,
#  'information': 280,
#  'office': 281,
#  'decision': 282,
#  'online': 283,
#  'state': 284,
#  'same': 285,
#  'court': 286,
#  'know': 287,
#  'action': 288,
#  'likely': 289,
#  'despite': 290,
#  'data': 291,
#  'o': 292,
#  'side': 293,
#  'president': 294,
#  'video': 295,
#  'making': 296,
#  'without': 297,
#  've': 298,
#  'give': 299,
#  'security': 300,
#  'cup': 301,
#  'campaign': 302,
#  'saying': 303,
#  'run': 304,
#  'anti': 305,
#  'figures': 306,
#  'found': 307,
#  'lost': 308,
#  'computer': 309,
#  'real': 310,
#  'offer': 311,
#  'away': 312,
#  'lot': 313,
#  'e': 314,
#  'seen': 315,
#  'national': 316,
#  'media': 317,
#  'star': 318,
#  'every': 319,
#  'executive': 320,
#  'times': 321,
#  'given': 322,
#  'using': 323,
#  'prices': 324,
#  'prime': 325,
#  'awards': 326,
#  'left': 327,
#  'oil': 328,
#  'line': 329,
#  'rise': 330,
#  'lord': 331,
#  'china': 332,
#  'interest': 333,
#  'earlier': 334,
#  'research': 335,
#  'analysts': 336,
#  'far': 337,
#  'shares': 338,
#  'able': 339,
#  'your': 340,
#  'biggest': 341,
#  'case': 342,
#  'later': 343,
#  'man': 344,
#  'december': 345,
#  'become': 346,
#  'match': 347,
#  'michael': 348,
#  'january': 349,
#  'player': 350,
#  'nations': 351,
#  'although': 352,
#  'countries': 353,
#  'again': 354,
#  'past': 355,
#  'legal': 356,
#  'early': 357,
#  '12': 358,
#  'foreign': 359,
#  'due': 360,
#  'whether': 361,
#  '20': 362,
#  'days': 363,
#  'cost': 364,
#  'recent': 365,
#  'bill': 366,
#  'cut': 367,
#  'microsoft': 368,
#  'leader': 369,
#  'current': 370,
#  'spending': 371,
#  'award': 372,
#  'financial': 373,
#  'internet': 374,
#  'does': 375,
#  'playing': 376,
#  'tory': 377,
#  'taking': 378,
#  'less': 379,
#  'went': 380,
#  'secretary': 381,
#  '0': 382,
#  'few': 383,
#  'support': 384,
#  'children': 385,
#  'john': 386,
#  'season': 387,
#  'hard': 388,
#  'thought': 389,
#  'played': 390,
#  'house': 391,
#  'look': 392,
#  'never': 393,
#  'major': 394,
#  'looking': 395,
#  'quarter': 396,
#  'pay': 397,
#  'budget': 398,
#  'ahead': 399,
#  'films': 400,
#  'latest': 401,
#  'strong': 402,
#  'david': 403,
#  'return': 404,
#  'until': 405,
#  'must': 406,
#  'control': 407,
#  'south': 408,
#  'access': 409,
#  'free': 410,
#  'held': 411,
#  'believe': 412,
#  'following': 413,
#  'important': 414,
#  'try': 415,
#  'face': 416,
#  'working': 417,
#  'role': 418,
#  'full': 419,
#  'yet': 420,
#  'different': 421,
#  'chancellor': 422,
#  'personal': 423,
#  'further': 424,
#  'something': 425,
#  'each': 426,
#  'power': 427,
#  'currently': 428,
#  'band': 429,
#  'sunday': 430,
#  'issue': 431,
#  'eu': 432,
#  'little': 433,
#  'tories': 434,
#  'rate': 435,
#  'always': 436,
#  'trade': 437,
#  'website': 438,
#  'coach': 439,
#  'sale': 440,
#  'include': 441,
#  'lead': 442,
#  'am': 443,
#  'scotland': 444,
#  'taken': 445,
#  'programme': 446,
#  'police': 447,
#  'local': 448,
#  'ms': 449,
#  'winning': 450,
#  'change': 451,
#  'series': 452,
#  'find': 453,
#  'chance': 454,
#  'claims': 455,
#  'political': 456,
#  'statement': 457,
#  'released': 458,
#  '30': 459,
#  'among': 460,
#  'broadband': 461,
#  'announced': 462,
#  'march': 463,
#  'mark': 464,
#  'injury': 465,
#  'japan': 466,
#  'ago': 467,
#  'meeting': 468,
#  'rights': 469,
#  'phones': 470,
#  'demand': 471,
#  'having': 472,
#  'share': 473,
#  'key': 474,
#  'performance': 475,
#  'behind': 476,
#  'sold': 477,
#  'title': 478,
#  '11': 479,
#  '8': 480,
#  'american': 481,
#  'point': 482,
#  'dollar': 483,
#  'might': 484,
#  'almost': 485,
#  'across': 486,
#  'council': 487,
#  'problem': 488,
#  'clear': 489,
#  'mail': 490,
#  'february': 491,
#  'increase': 492,
#  'manager': 493,
#  'done': 494,
#  'wednesday': 495,
#  'rugby': 496,
#  'consumer': 497,
#  'search': 498,
#  'continue': 499,
#  'weeks': 500,
#  'enough': 501,
#  'minutes': 502,
#  'head': 503,
#  'network': 504,
#  'things': 505,
#  'here': 506,
#  'tony': 507,
#  '9': 508,
#  'tuesday': 509,
#  'chairman': 510,
#  'costs': 511,
#  '50': 512,
#  'men': 513,
#  'keep': 514,
#  'price': 515,
#  'india': 516,
#  'least': 517,
#  'problems': 518,
#  'term': 519,
#  'bid': 520,
#  'needed': 521,
#  'ever': 522,
#  'once': 523,
#  'young': 524,
#  'low': 525,
#  'today': 526,
#  'women': 527,
#  '25': 528,
#  'war': 529,
#  'plan': 530,
#  'getting': 531,
#  'victory': 532,
#  'members': 533,
#  'means': 534,
#  'coming': 535,
#  'hold': 536,
#  'rather': 537,
#  'investment': 538,
#  'content': 539,
#  'running': 540,
#  'warned': 541,
#  'rates': 542,
#  'possible': 543,
#  'fans': 544,
#  'november': 545,
#  'result': 546,
#  'within': 547,
#  'monday': 548,
#  'level': 549,
#  'act': 550,
#  'production': 551,
#  'forward': 552,
#  '18': 553,
#  'league': 554,
#  'saturday': 555,
#  'centre': 556,
#  'williams': 557,
#  'form': 558,
#  'song': 559,
#  'list': 560,
#  'sir': 561,
#  'asked': 562,
#  'chelsea': 563,
#  'job': 564,
#  'commission': 565,
#  'huge': 566,
#  '15': 567,
#  'global': 568,
#  'mps': 569,
#  'beat': 570,
#  'apple': 571,
#  'available': 572,
#  'jones': 573,
#  'jobs': 574,
#  'd': 575,
#  'allow': 576,
#  'break': 577,
#  'policy': 578,
#  'previous': 579,
#  'web': 580,
#  'stock': 581,
#  'friday': 582,
#  'issues': 583,
#  'vote': 584,
#  '2001': 585,
#  'close': 586,
#  'thing': 587,
#  'though': 588,
#  'known': 589,
#  'version': 590,
#  'showed': 591,
#  'city': 592,
#  'christmas': 593,
#  'fourth': 594,
#  'success': 595,
#  'album': 596,
#  'committee': 597,
#  'single': 598,
#  'union': 599,
#  'networks': 600,
#  'several': 601,
#  'buy': 602,
#  'main': 603,
#  'site': 604,
#  'live': 605,
#  'why': 606,
#  'doing': 607,
#  'reported': 608,
#  'aid': 609,
#  'book': 610,
#  'others': 611,
#  'let': 612,
#  'lib': 613,
#  'human': 614,
#  'reports': 615,
#  'york': 616,
#  'football': 617,
#  'trying': 618,
#  'sport': 619,
#  'italy': 620,
#  'virus': 621,
#  'customers': 622,
#  'ministers': 623,
#  'actor': 624,
#  'higher': 625,
#  'shows': 626,
#  'failed': 627,
#  'consumers': 628,
#  'hope': 629,
#  'agreed': 630,
#  'led': 631,
#  'development': 632,
#  'wants': 633,
#  'name': 634,
#  'competition': 635,
#  'september': 636,
#  'short': 637,
#  'call': 638,
#  'cash': 639,
#  'career': 640,
#  'parliament': 641,
#  'wanted': 642,
#  'total': 643,
#  'board': 644,
#  'small': 645,
#  'sony': 646,
#  'meet': 647,
#  'choice': 648,
#  'popular': 649,
#  'prize': 650,
#  'parties': 651,
#  'points': 652,
#  'nothing': 653,
#  'iraq': 654,
#  'rules': 655,
#  'thursday': 656,
#  'rose': 657,
#  'eight': 658,
#  'project': 659,
#  'race': 660,
#  'event': 661,
#  'recently': 662,
#  '17': 663,
#  'comes': 664,
#  'movie': 665,
#  'received': 666,
#  'profits': 667,
#  'saw': 668,
#  'charles': 669,
#  'health': 670,
#  'liberal': 671,
#  'fact': 672,
#  'dvd': 673,
#  'difficult': 674,
#  '100': 675,
#  'instead': 676,
#  'release': 677,
#  'bit': 678,
#  'order': 679,
#  'olympic': 680,
#  'weekend': 681,
#  'mean': 682,
#  'october': 683,
#  'late': 684,
#  'family': 685,
#  'calls': 686,
#  'boss': 687,
#  'sites': 688,
#  'box': 689,
#  'large': 690,
#  'television': 691,
#  'trial': 692,
#  'test': 693,
#  'similar': 694,
#  'involved': 695,
#  'growing': 696,
#  'summer': 697,
#  'paid': 698,
#  'festival': 699,
#  'champion': 700,
#  'french': 701,
#  'attacks': 702,
#  'singer': 703,
#  'needs': 704,
#  'co': 705,
#  'debt': 706,
#  'devices': 707,
#  'street': 708,
#  'results': 709,
#  'annual': 710,
#  'didn': 711,
#  'car': 712,
#  'sure': 713,
#  'evidence': 714,
#  'denied': 715,
#  'feel': 716,
#  'giant': 717,
#  'goal': 718,
#  'paul': 719,
#  'russian': 720,
#  'products': 721,
#  'liverpool': 722,
#  'immigration': 723,
#  'pressure': 724,
#  'accused': 725,
#  'pc': 726,
#  'association': 727,
#  'tour': 728,
#  'stop': 729,
#  'position': 730,
#  'education': 731,
#  'stage': 732,
#  'manchester': 733,
#  'robinson': 734,
#  'largest': 735,
#  'simply': 736,
#  'launch': 737,
#  'cannot': 738,
#  'appeal': 739,
#  'launched': 740,
#  'special': 741,
#  'round': 742,
#  'ensure': 743,
#  'boost': 744,
#  'potential': 745,
#  'gaming': 746,
#  'senior': 747,
#  'rock': 748,
#  'irish': 749,
#  'talks': 750,
#  'claim': 751,
#  'gordon': 752,
#  'martin': 753,
#  'believes': 754,
#  '40': 755,
#  'yukos': 756,
#  '2002': 757,
#  'per': 758,
#  'changes': 759,
#  'fall': 760,
#  'africa': 761,
#  '16': 762,
#  'chart': 763,
#  'opening': 764,
#  'australian': 765,
#  'sent': 766,
#  'stars': 767,
#  'leading': 768,
#  'themselves': 769,
#  'hopes': 770,
#  'fell': 771,
#  'conference': 772,
#  'fund': 773,
#  'love': 774,
#  'started': 775,
#  'speed': 776,
#  'age': 777,
#  'anything': 778,
#  'provide': 779,
#  '13': 780,
#  'independent': 781,
#  'together': 782,
#  'remain': 783,
#  'seven': 784,
#  'ball': 785,
#  'black': 786,
#  'extra': 787,
#  'included': 788,
#  'pre': 789,
#  'range': 790,
#  'systems': 791,
#  'official': 792,
#  'university': 793,
#  'ukip': 794,
#  'value': 795,
#  'standard': 796,
#  'dr': 797,
#  '24': 798,
#  'card': 799,
#  'voters': 800,
#  'cards': 801,
#  'school': 802,
#  'impact': 803,
#  '2000': 804,
#  'helped': 805,
#  'germany': 806,
#  'makes': 807,
#  'drive': 808,
#  'squad': 809,
#  'fight': 810,
#  'conservative': 811,
#  'either': 812,
#  'grand': 813,
#  'bush': 814,
#  'entertainment': 815,
#  'department': 816,
#  'wrong': 817,
#  'taxes': 818,
#  'v': 819,
#  'whole': 820,
#  'claimed': 821,
#  'winner': 822,
#  'night': 823,
#  'turn': 824,
#  'commons': 825,
#  'stand': 826,
#  'german': 827,
#  'air': 828,
#  'spam': 829,
#  'proposals': 830,
#  'kilroy': 831,
#  '14': 832,
#  'spent': 833,
#  'charge': 834,
#  'meanwhile': 835,
#  'compared': 836,
#  'oscar': 837,
#  '2006': 838,
#  'laws': 839,
#  'comedy': 840,
#  'history': 841,
#  'll': 842,
#  'trust': 843,
#  'actress': 844,
#  'process': 845,
#  'sector': 846,
#  'authorities': 847,
#  'private': 848,
#  'investors': 849,
#  'poor': 850,
#  'idea': 851,
#  'date': 852,
#  'energy': 853,
#  'officials': 854,
#  'charges': 855,
#  'everyone': 856,
#  'press': 857,
#  'create': 858,
#  'download': 859,
#  'areas': 860,
#  'numbers': 861,
#  'smith': 862,
#  'speech': 863,
#  'cuts': 864,
#  'fraud': 865,
#  'hours': 866,
#  'bring': 867,
#  'quite': 868,
#  'training': 869,
#  'roddick': 870,
#  'scottish': 871,
#  'newspaper': 872,
#  'original': 873,
#  'everything': 874,
#  'takes': 875,
#  'google': 876,
#  'euros': 877,
#  'sell': 878,
#  'became': 879,
#  'exchange': 880,
#  'generation': 881,
#  'mobiles': 882,
#  'australia': 883,
#  'happy': 884,
#  'arsenal': 885,
#  'worked': 886,
#  'screen': 887,
#  'admitted': 888,
#  'average': 889,
#  'survey': 890,
#  'mike': 891,
#  'double': 892,
#  'brought': 893,
#  'james': 894,
#  'concerns': 895,
#  'file': 896,
#  'opportunity': 897,
#  'forced': 898,
#  'gave': 899,
#  'west': 900,
#  'indian': 901,
#  'bought': 902,
#  'story': 903,
#  'tough': 904,
#  'target': 905,
#  'america': 906,
#  'soon': 907,
#  'hand': 908,
#  'stay': 909,
#  'itself': 910,
#  'agency': 911,
#  'raise': 912,
#  'groups': 913,
#  'period': 914,
#  'kennedy': 915,
#  'view': 916,
#  'audience': 917,
#  'central': 918,
#  'silk': 919,
#  'remains': 920,
#  'turned': 921,
#  'bad': 922,
#  'focus': 923,
#  'russia': 924,
#  'alan': 925,
#  'analyst': 926,
#  'confirmed': 927,
#  'course': 928,
#  'widely': 929,
#  'experience': 930,
#  'care': 931,
#  'force': 932,
#  'amount': 933,
#  '19': 934,
#  'community': 935,
#  'reached': 936,
#  'pop': 937,
#  'previously': 938,
#  'april': 939,
#  'non': 940,
#  'hollywood': 941,
#  'quality': 942,
#  'followed': 943,
#  'himself': 944,
#  'campbell': 945,
#  'track': 946,
#  'images': 947,
#  'debate': 948,
#  'challenge': 949,
#  'files': 950,
#  'levels': 951,
#  'particularly': 952,
#  'drugs': 953,
#  'often': 954,
#  'moment': 955,
#  'body': 956,
#  'situation': 957,
#  'row': 958,
#  'area': 959,
#  'details': 960,
#  'peer': 961,
#  'blunkett': 962,
#  'technologies': 963,
#  'easy': 964,
#  'message': 965,
#  'attack': 966,
#  'davis': 967,
#  'via': 968,
#  'johnson': 969,
#  'schools': 970,
#  'member': 971,
#  'captain': 972,
#  'nine': 973,
#  'named': 974,
#  'step': 975,
#  'ways': 976,
#  'front': 977,
#  'concerned': 978,
#  'whose': 979,
#  'definition': 980,
#  'looked': 981,
#  'comments': 982,
#  'minute': 983,
#  'ban': 984,
#  'tsunami': 985,
#  'civil': 986,
#  'messages': 987,
#  'andy': 988,
#  'leave': 989,
#  'shown': 990,
#  'shot': 991,
#  'outside': 992,
#  'anyone': 993,
#  'battle': 994,
#  'lives': 995,
#  'june': 996,
#  'nearly': 997,
#  'lords': 998,
#  'fast': 999,
#  'post': 1000,
#  ...}

# %%
tokenizer.texts_to_sequences(['the cat sat on my table'])
# Out:
# [[2, 1, 1, 13, 127, 2286]]

# %%
train_sequences = tokenizer.texts_to_sequences(train_articles)
len(train_sequences)
# Out:
# 1780

# %%
len(train_sequences[8]),
# Out:
# (522,)

# %%
train_padded = pad_sequences(train_sequences, maxlen=max_length,)

# %%
len(train_padded),len(train_padded[0])
# Out:
# (1780, 200)

# %%
len(train_sequences[8]),len(train_padded[8])
# Out:
# (522, 200)

# %%
validation_sequences = tokenizer.texts_to_sequences(validation_articles)
validation_padded = pad_sequences(validation_sequences, maxlen=max_length)

# %%
set(labels)
# Out:
# {'business', 'entertainment', 'politics', 'sport', 'tech'}

# %%
label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(labels)

training_label_seq = np.array(label_tokenizer.texts_to_sequences(train_labels))
validation_label_seq = np.array(label_tokenizer.texts_to_sequences(validation_labels))

# %%
label_tokenizer.word_index
# Out:
# {'sport': 1, 'business': 2, 'politics': 3, 'tech': 4, 'entertainment': 5}

# %%
train_labels
# Out:
# array(['entertainment', 'business', 'business', ..., 'tech', 'sport',
#        'tech'], shape=(1780,), dtype=object)

# %%
training_label_seq
# Out:
# array([[5],
#        [2],
#        [2],
#        ...,
#        [4],
#        [1],
#        [4]], shape=(1780, 1))

# %%
train_labels[0], training_label_seq[0]
# Out:
# ('entertainment', array([5]))

# %% [markdown]
# ## Apply RNN

# %%
model = Sequential()
model.add(Embedding(vocab_size,embedding_dim , input_length=100))
model.build(input_shape=(None, 100))
model.add(Dropout(0.2))
model.add(SimpleRNN(units = embedding_dim))
model.add(Dropout(0.2))
model.add(Dense(6,activation='softmax'))
model.summary()
# Out:
# c:\Users\Lenovo\Desktop\DEPI(R_2)\ML_git\GIZ4_AIS2_S1_Ml\.env\Lib\site-packages\keras\src\layers\core\embedding.py:103: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 100, 64)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 328,646 (1.25 MB)
#  Trainable params: 328,646 (1.25 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.backend.clear_session()
from tensorflow.keras.optimizers import AdamW

adam_w = AdamW(learning_rate=0.001)

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# search on sparse_categorical_crossentropy
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
num_epochs = 20
history = model.fit(train_padded, training_label_seq, epochs=num_epochs,
                    validation_data=(validation_padded, validation_label_seq),
                    verbose=2)
# Out:
# Epoch 1/20
# 56/56 - 4s - 69ms/step - accuracy: 0.2258 - loss: 1.6788 - val_accuracy: 0.2697 - val_loss: 1.6083
# Epoch 2/20
# 56/56 - 2s - 38ms/step - accuracy: 0.4309 - loss: 1.4760 - val_accuracy: 0.3011 - val_loss: 1.6184
# Epoch 3/20
# 56/56 - 3s - 50ms/step - accuracy: 0.7225 - loss: 1.1037 - val_accuracy: 0.3236 - val_loss: 1.5989
# Epoch 4/20
# 56/56 - 3s - 59ms/step - accuracy: 0.9073 - loss: 0.5802 - val_accuracy: 0.3258 - val_loss: 1.6861
# Epoch 5/20
# 56/56 - 2s - 37ms/step - accuracy: 0.9747 - loss: 0.2542 - val_accuracy: 0.3393 - val_loss: 1.7428
# Epoch 6/20
# 56/56 - 2s - 31ms/step - accuracy: 0.9989 - loss: 0.0936 - val_accuracy: 0.3281 - val_loss: 1.8852
# Epoch 7/20
# 56/56 - 3s - 57ms/step - accuracy: 1.0000 - loss: 0.0415 - val_accuracy: 0.3213 - val_loss: 2.0237
# Epoch 8/20
# 56/56 - 2s - 40ms/step - accuracy: 1.0000 - loss: 0.0239 - val_accuracy: 0.3079 - val_loss: 2.1267
# Epoch 9/20
# 56/56 - 2s - 41ms/step - accuracy: 1.0000 - loss: 0.0178 - val_accuracy: 0.3169 - val_loss: 2.1304
# Epoch 10/20
# 56/56 - 2s - 39ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.3236 - val_loss: 2.1816
# Epoch 11/20
# 56/56 - 2s - 37ms/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.3124 - val_loss: 2.2586
# Epoch 12/20
# 56/56 - 3s - 61ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.3146 - val_loss: 2.2817
# Epoch 13/20
# 56/56 - 3s - 45ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.3326 - val_loss: 2.2837
# Epoch 14/20
# 56/56 - 2s - 39ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.3079 - val_loss: 2.3449
# Epoch 15/20
# 56/56 - 3s - 52ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.3191 - val_loss: 2.3685
# Epoch 16/20
# 56/56 - 3s - 48ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.3146 - val_loss: 2.4001
# Epoch 17/20
# 56/56 - 3s - 47ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.3371 - val_loss: 2.4013
# Epoch 18/20
# 56/56 - 3s - 45ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.3326 - val_loss: 2.4335
# Epoch 19/20
# 56/56 - 4s - 73ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.3348 - val_loss: 2.4500
# Epoch 20/20
# 56/56 - 6s - 107ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.3416 - val_loss: 2.4587

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
txt = ["blair prepares to name poll date tony blair is likely to name 5 may as election day when parliament returns from its easter break  the bbc s political editor has learned.  andrew marr says mr blair will ask the queen on 4 or 5 april to dissolve parliament at the end of that week. mr blair has so far resisted calls for him to name the day but all parties have stepped up campaigning recently. downing street would not be drawn on the claim  saying election timing was a matter for the prime minister.  a number 10 spokeswoman would only say:  he will announce an election when he wants to announce an election.  the move will signal a frantic week at westminster as the government is likely to try to get key legislation through parliament. the government needs its finance bill  covering the budget plans  to be passed before the commons closes for business at the end of the session on 7 april.  but it will also seek to push through its serious and organised crime bill and id cards bill. mr marr said on wednesday s today programme:  there s almost nobody at a senior level inside the government or in parliament itself who doesn t expect the election to be called on 4 or 5 april.  as soon as the commons is back after the short easter recess  tony blair whips up to the palace  asks the queen to dissolve parliament ... and we re going.  the labour government officially has until june 2006 to hold general election  but in recent years governments have favoured four-year terms."]

seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
labels = ['sport', 'bussiness', 'politics', 'tech', 'entertainment']

print(pred)
print(np.argmax(pred))
print(labels[np.argmax(pred)-1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# [[2.3165907e-04 1.3029380e-04 1.5434927e-04 9.9928802e-01 1.6851837e-04
#   2.7168706e-05]]
# 3
# politics

# %%
txt = ["call to save manufacturing jobs the trades union congress (tuc) is calling on the government to stem job losses in manufacturing firms by reviewing the help it gives companies.  the tuc said in its submission before the budget that action is needed because of 105 000 jobs lost from the sector over the last year. it calls for better pensions  child care provision and decent wages. the 36-page submission also urges the government to examine support other european countries provide to industry. tuc general secretary brendan barber called for  a commitment to policies that will make a real difference to the lives of working people.    greater investment in childcare strategies and the people delivering that childcare will increases the options available to working parents   he said.  a commitment to our public services and manufacturing sector ensures that we can continue to compete on a global level and deliver the frontline services that this country needs.  he also called for  practical measures  to help pensioners  especially women who he said  are most likely to retire in poverty . the submission also calls for decent wages and training for people working in the manufacturing sector."]

seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
labels = ['sport', 'bussiness', 'politics', 'tech', 'entertainment']

print(pred)
print(np.argmax(pred))
print(labels[np.argmax(pred)-1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# [[1.09204404e-04 1.41381111e-04 9.99410391e-01 9.11586467e-05
#   2.69114880e-05 2.21005364e-04]]
# 2
# bussiness

# %% [markdown]
# ## LSTM

# %%
tf.keras.backend.clear_session()

# %%
# LSTM model
model = Sequential()
model.add(Embedding(vocab_size,embedding_dim ))
model.build(input_shape=(None, 100))
model.add(Dropout(0.5))
model.add(Bidirectional(LSTM(embedding_dim)))
model.add(Dense(6,activation='softmax' ))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 100, 64)        │       320,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 128)            │        66,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 386,822 (1.48 MB)
#  Trainable params: 386,822 (1.48 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
num_epochs = 20
history = model.fit(train_padded, training_label_seq, epochs=num_epochs,
                    validation_data=(validation_padded, validation_label_seq),
                    verbose=2)
# Out:
# Epoch 1/20
# 56/56 - 7s - 125ms/step - accuracy: 0.2579 - loss: 1.6433 - val_accuracy: 0.2831 - val_loss: 1.5244
# Epoch 2/20
# 56/56 - 4s - 74ms/step - accuracy: 0.4438 - loss: 1.3089 - val_accuracy: 0.4225 - val_loss: 1.1946
# Epoch 3/20
# 56/56 - 4s - 74ms/step - accuracy: 0.6421 - loss: 0.9568 - val_accuracy: 0.5798 - val_loss: 0.9718
# Epoch 4/20
# 56/56 - 5s - 83ms/step - accuracy: 0.7124 - loss: 0.8005 - val_accuracy: 0.6652 - val_loss: 0.8853
# Epoch 5/20
# 56/56 - 4s - 66ms/step - accuracy: 0.8433 - loss: 0.5693 - val_accuracy: 0.7730 - val_loss: 0.7167
# Epoch 6/20
# 56/56 - 4s - 64ms/step - accuracy: 0.8854 - loss: 0.3948 - val_accuracy: 0.8719 - val_loss: 0.4229
# Epoch 7/20
# 56/56 - 4s - 63ms/step - accuracy: 0.9607 - loss: 0.1649 - val_accuracy: 0.8989 - val_loss: 0.3494
# Epoch 8/20
# 56/56 - 3s - 62ms/step - accuracy: 0.9663 - loss: 0.1325 - val_accuracy: 0.8876 - val_loss: 0.3502
# Epoch 9/20
# 56/56 - 3s - 61ms/step - accuracy: 0.9556 - loss: 0.1574 - val_accuracy: 0.8360 - val_loss: 0.5713
# Epoch 10/20
# 56/56 - 3s - 62ms/step - accuracy: 0.9551 - loss: 0.2301 - val_accuracy: 0.8719 - val_loss: 0.4731
# Epoch 11/20
# 56/56 - 4s - 70ms/step - accuracy: 0.9494 - loss: 0.1774 - val_accuracy: 0.8787 - val_loss: 0.4250
# Epoch 12/20
# 56/56 - 4s - 63ms/step - accuracy: 0.9781 - loss: 0.0806 - val_accuracy: 0.8831 - val_loss: 0.4033
# Epoch 13/20
# 56/56 - 3s - 61ms/step - accuracy: 0.9798 - loss: 0.0626 - val_accuracy: 0.8697 - val_loss: 0.4225
# Epoch 14/20
# 56/56 - 3s - 62ms/step - accuracy: 0.9792 - loss: 0.0792 - val_accuracy: 0.8045 - val_loss: 0.6052
# Epoch 15/20
# 56/56 - 4s - 69ms/step - accuracy: 0.9680 - loss: 0.1089 - val_accuracy: 0.8899 - val_loss: 0.3515
# Epoch 16/20
# 56/56 - 10s - 171ms/step - accuracy: 0.9927 - loss: 0.0322 - val_accuracy: 0.9011 - val_loss: 0.3338
# Epoch 17/20
# 56/56 - 7s - 123ms/step - accuracy: 0.9966 - loss: 0.0176 - val_accuracy: 0.9169 - val_loss: 0.3401
# Epoch 18/20
# 56/56 - 7s - 127ms/step - accuracy: 0.9983 - loss: 0.0111 - val_accuracy: 0.9213 - val_loss: 0.3223
# Epoch 19/20
# 56/56 - 7s - 123ms/step - accuracy: 0.9972 - loss: 0.0194 - val_accuracy: 0.9146 - val_loss: 0.3356
# Epoch 20/20
# 56/56 - 7s - 131ms/step - accuracy: 0.9989 - loss: 0.0133 - val_accuracy: 0.9011 - val_loss: 0.3478

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
txt = ["blair prepares to name poll date tony blair is likely to name 5 may as election day when parliament returns from its easter break  the bbc s political editor has learned.  andrew marr says mr blair will ask the queen on 4 or 5 april to dissolve parliament at the end of that week. mr blair has so far resisted calls for him to name the day but all parties have stepped up campaigning recently. downing street would not be drawn on the claim  saying election timing was a matter for the prime minister.  a number 10 spokeswoman would only say:  he will announce an election when he wants to announce an election.  the move will signal a frantic week at westminster as the government is likely to try to get key legislation through parliament. the government needs its finance bill  covering the budget plans  to be passed before the commons closes for business at the end of the session on 7 april.  but it will also seek to push through its serious and organised crime bill and id cards bill. mr marr said on wednesday s today programme:  there s almost nobody at a senior level inside the government or in parliament itself who doesn t expect the election to be called on 4 or 5 april.  as soon as the commons is back after the short easter recess  tony blair whips up to the palace  asks the queen to dissolve parliament ... and we re going.  the labour government officially has until june 2006 to hold general election  but in recent years governments have favoured four-year terms."]

seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
labels = ['sport', 'bussiness', 'politics', 'tech', 'entertainment']

print(pred)
print(np.argmax(pred))
print(labels[np.argmax(pred)-1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# [[4.8183956e-05 2.5320551e-05 8.6532423e-04 9.9788660e-01 1.1115074e-03
#   6.3114247e-05]]
# 3
# politics

# %%
txt = ["call to save manufacturing jobs the trades union congress (tuc) is calling on the government to stem job losses in manufacturing firms by reviewing the help it gives companies.  the tuc said in its submission before the budget that action is needed because of 105 000 jobs lost from the sector over the last year. it calls for better pensions  child care provision and decent wages. the 36-page submission also urges the government to examine support other european countries provide to industry. tuc general secretary brendan barber called for  a commitment to policies that will make a real difference to the lives of working people.    greater investment in childcare strategies and the people delivering that childcare will increases the options available to working parents   he said.  a commitment to our public services and manufacturing sector ensures that we can continue to compete on a global level and deliver the frontline services that this country needs.  he also called for  practical measures  to help pensioners  especially women who he said  are most likely to retire in poverty . the submission also calls for decent wages and training for people working in the manufacturing sector."]

seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
labels = ['sport', 'bussiness', 'politics', 'tech', 'entertainment']

print(pred)
print(np.argmax(pred))
print(labels[np.argmax(pred)-1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# [[1.0399734e-05 6.4590286e-06 9.9887019e-01 3.1045309e-04 5.0402852e-04
#   2.9841831e-04]]
# 2
# bussiness

# %% [markdown]
# # GRU (Gated Recurrent Unit)
#
# At each time step, the GRU updates its memory using:
#
# * the current input (x_t)
# * the previous hidden state (h_{t-1})
#
# ---
#
# ## Core Components
#
# ### 1. Reset Gate
#
# **Role:**
#
# * Decides how much of the **past memory (h_{t-1}) to use** when creating new information
# * Can ignore irrelevant past or keep important context
#
# ---
#
# ### 2. Candidate Memory
#
# **Role:**
#
# * Represents the **new information** the model wants to add
# * Built from:
#
#   * current input (x_t)
#   * **filtered past memory (h_{t-1})** after reset gate
#
# ---
#
# ### 3. Update Gate
#
# **Role:**
#
# * Decides how much of the **new information replaces old memory**
# * Uses both:
#
#   * current input (x_t)
#   * previous hidden state (h_{t-1})
#
# ---
#
# ### 4. Final Memory (Hidden State)
#
# **Role:**
#
# * The new memory (h_t) is a **mix of**:
#
#   * old memory (h_{t-1})
#   * new candidate information
#
# ---
#
# ## Flow
#
# ```
# h_{t-1} and x_t → [Reset Gate] → Build Candidate → [Update Gate] → h_t
# ```
#
# ---
#
# ## Key Insights
#
# * Reset Gate → controls **what part of h_{t-1} is used**
# * Update Gate → controls **how h_{t-1} is updated into h_t**
#
# ---
#
# ## Intuition
#
# * Reset Gate: *“How much of h_{t-1} should I consider?”*
# * Update Gate: *“How much of h_t should come from new info vs h_{t-1}?”*
#
# ---
#
# ## One-line Summary
#
# > GRU = **use x_t and filtered h_{t-1} to build new info, then update h_{t-1} into h_t adaptively**
