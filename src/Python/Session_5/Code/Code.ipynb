# %%
from abc import ABC , abstractmethod

class Animal(ABC):
    
    @abstractmethod
    def move(self):
        pass

class Bird(Animal):
    
    def move(self):
        print("Bird")

class Cat(Animal):

    def move(self):
        print("Bird")

# %%
a = Bird()
a.move()
# Out:
# Bird

# %%
class A():
    def do_this(self):
        print("I'm in A")

class B():
    pass

class C():
    def do_this(self):
        print("I'm in C")

class D(A,C):
    pass

x = D()
x.do_this()
# Out:
# I'm in A

# %%
try:
    5/0
except:
    print("not accept to divided by zero")
# Out:
# not accept to divided by zero

# %%
try:
    x=10
    y=int(input())
    x/y
    
except Exception as e:
    print(e)
# Out:
# division by zero

# %%
try:
    print(Z)

except:
    print("something went wrong")

finally:
    print("the 'try except1' is finished")
# Out:
# something went wrong
# the 'try except1' is finished

# %%
import os

base = r"C:\Users\Lenovo\Desktop\DEPI(R_2)\ML_git\GIZ4_AIS2_S1_Ml\src\Python"
type(base)
# Out:
# str

# %%
os.listdir(base)
# Out:
# ['Final_project',
#  'Session_1',
#  'Session_2',
#  'session_3',
#  'session_4',
#  'Session_5']

# %%
os.remove(base+'/rem.txt')

# %%
directory = "./tmp_directory_test_again"

if not os.path.exists(directory):
    os.makedirs(directory)

else:
    print("directory already exists:" , directory)
# Out:
# directory already exists: ./tmp_directory_test_again

# %%
import os

def make_directory(path):
    if not os.path.exists(path):
        os.makedirs(path)
        return "Directory created"
    else:
        return "Directory already exists"

# %%
result = make_directory("./tmp_directory_test")
print(result)
# Out:
# Directory already exists

# %%
import os

path = "tmp_directory"

if not os.path.exists(path):
    os.makedirs(path)

for i in range(20):
    inner_path = os.path.join(path, "dir_" + str(i))
    if not os.path.exists(inner_path):
        os.makedirs(inner_path)

# %%
import os

def create_directories(base_path, count=20):
    if not os.path.exists(base_path):
        os.makedirs(base_path)

    for i in range(count):
        inner_path = os.path.join(base_path, "dir_" + str(i))
        if not os.path.exists(inner_path):
            os.makedirs(inner_path)

# %%
create_directories("tmp_directory")

# %%
with open("./tmp_directory_test/text_1.txt", "a+") as file:


    file.write(" New line added\n") 

    file.seek(0)  

    updated_content = file.read() 

    print(updated_content)
# Out:
#  New line added

# %%
f = open("./tmp_directory_test/text_1.txt", "w")
f.write("Hello________")
f.close()

f = open("./tmp_directory_test/text_1.txt", "r")
print(f.read())
f.close()
# Out:
# Hello________

# %%
import random
from prettytable import prettytable

u = "test"
p = "1111"

while True:
    x = input("enter ur username")
    if x == u:
        y = input("enter ur password")
        
        if y == p:
            s = random.randrange(10000, 1000000)
            
            print("verfication code is: " , s)
            
            while True:
                l = int(input("enter ur verfication code"))
                if l == s:
                    print("access granted!")
                    break
                else:
                    print("invalid verfication code")
            break        
        else:
            print("incorrect pass")
            continue

    else:
        print("incorrect username. please try again")
        continue
# Out:
# verfication code is:  111614
# access granted!
