# %%
list = [3,4,5,6,7]
list[2] = 4
list
# Out:
# [3, 4, 4, 6, 7]

# %%
name , age , grade = 'Hazem' , 22 , 3.375

# %%
print(f"my name is {name} and my age is {age} and my grade is {grade}")
# Out:
# my name is Hazem and my age is 22 and my grade is 3.375

# %%
age = 20
interest = ("data analysis")

if age > 18 and interest == 'data analysis':
    print('this is hazem')

else:
    print('this is another one')
# Out:
# this is hazem

# %%
try:

    Grade = float(input('enter your grade'))

    if Grade >= 90:
        print("your grade is excellent")


    elif Grade >= 80:
        print("your grade is good")

# except ValueError:
#     print('ValueError')

except Exception as e:
    print(e)
# Out:
# could not convert string to float: 'k'

# %%
def grade_sys():

    Grade = float(input('enter your grade'))

    if Grade >= 90:
        print("your grade is excellent")


    elif Grade >= 80:
        print("your grade is good")

grade_sys()
# Out:
# your grade is excellent

# %%
temp = float(input('enter the temperture'))

if temp > 30:
    print('hot')

else:
    print('cold')
# Out:
# hot

# %%
temp = float(input('enter the temperture'))

result = 'hot' if temp > 30 else 'cold'
result
# Out:
# 'cold'

# %%
def sum(n1 , n2):
    return n1+n2

sum(9,3)
# Out:
# 12

# %%
add = lambda n1,n2: n1+n2
add(5,9) , add(7,9)
# Out:
# (14, 16)

# %%
for i in range (1,11):
    print (f"this is table {i}")
    for j in range(1,11):
        print(f'{i}  * {j} = {i*j}')
# Out:
# this is table 1
# 1  * 1 = 1
# 1  * 2 = 2
# 1  * 3 = 3
# 1  * 4 = 4
# 1  * 5 = 5
# 1  * 6 = 6
# 1  * 7 = 7
# 1  * 8 = 8
# 1  * 9 = 9
# 1  * 10 = 10
# this is table 2
# 2  * 1 = 2
# 2  * 2 = 4
# 2  * 3 = 6
# 2  * 4 = 8
# 2  * 5 = 10
# 2  * 6 = 12
# 2  * 7 = 14
# 2  * 8 = 16
# 2  * 9 = 18
# 2  * 10 = 20
# this is table 3
# 3  * 1 = 3
# 3  * 2 = 6
# 3  * 3 = 9
# 3  * 4 = 12
# 3  * 5 = 15
# 3  * 6 = 18
# 3  * 7 = 21
# 3  * 8 = 24
# 3  * 9 = 27
# 3  * 10 = 30
# this is table 4
# 4  * 1 = 4
# 4  * 2 = 8
# 4  * 3 = 12
# 4  * 4 = 16
# 4  * 5 = 20
# 4  * 6 = 24
# 4  * 7 = 28
# 4  * 8 = 32
# 4  * 9 = 36
# 4  * 10 = 40
# this is table 5
# 5  * 1 = 5
# 5  * 2 = 10
# 5  * 3 = 15
# 5  * 4 = 20
# 5  * 5 = 25
# 5  * 6 = 30
# 5  * 7 = 35
# 5  * 8 = 40
# 5  * 9 = 45
# 5  * 10 = 50
# this is table 6
# 6  * 1 = 6
# 6  * 2 = 12
# 6  * 3 = 18
# 6  * 4 = 24
# 6  * 5 = 30
# 6  * 6 = 36
# 6  * 7 = 42
# 6  * 8 = 48
# 6  * 9 = 54
# 6  * 10 = 60
# this is table 7
# 7  * 1 = 7
# 7  * 2 = 14
# 7  * 3 = 21
# ...

# %%
lst = [1,2,3,4,5,6,7,8,9]
result = [i**2 for i in lst if i % 2 == 0]

result
# Out:
# [4, 16, 36, 64]

# %%
lst = [1,2,3,4,5,6,7,8,9]
resullt = []
for i in lst:
    if i % 2 == 0:
        resullt.append(i**2)

resullt
# Out:
# [4, 16, 36, 64]
