# %%
def reverse_vocab(s):
    """
    param_1 = recive text from user
    type param : string

    return : return string
    type return : string
    

    """
    st_1 = s.split(" ")
    new_st = st_1[::-1]
    new_str = " ".join(new_st)

    return new_str 

reverse_vocab("Hazem Amr Mohamed")
# Out:
# 'Mohamed Amr Hazem'

# %%
import random

def generate_pass (L):

    chars = "abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
    password = ""

    for _ in range(L):
        password += random.choice(chars)

    return password

generate_pass(5)
# Out:
# 'h$OvO'

# %%
def count_unique_words(words):
    
    unique_words = set(words)
    counts = {word: 0 for word in unique_words}

    for i in unique_words:
        for j in words:
            if i == j:
                counts[i] += 1

    return counts

lst = ["Welcome", "Ali", "Hi", "Ali", "No", "Hi", "No", "Ali", "No", "Ali"]
print(count_unique_words(lst))
# Out:
# {'Hi': 2, 'Ali': 4, 'Welcome': 1, 'No': 3}

# %%
import random

responses = {
    "hello" : ["hello!" , "hi there" , "greetings!"],
    "how are you" : ["I'm doing well" , "thank you" , "how are you?"],
    "goodbye" : ["Goodbye" , " seeyou later" , "farewell!"],
    "default" : ["I'am sorry" , "I didn't understand" , "colud you please rephase that?"]
}

def get_response(user_input):

    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
        
    return random.choice(responses["default"])


def chat_bot():

    print("chat_bot : Hi, How can i help you today?")

    while True:
        user_input = input("User:  ").lower()
        response = get_response(user_input)

        print("chat_bot: ", response)

        if user_input == "goodbye":
            break

# %%
chat_bot()
# Out:
# chat_bot : Hi, How can i help you today?
# chat_bot:  hello!
# chat_bot:  Goodbye

# %%
"""
this class

"""

class STUDENT_INFO:

    student_name = 'Hazem'
    std_age = 22
    std_GPA = 3.321
    gender = "male"

    def std_info(self):
        print("hello world")

# %%
s1 = STUDENT_INFO()

# %%
s1.std_info()
# Out:
# hello world

# %%
class test:

    def info(self):
        print(self)

# %%
x = test()

# %%
print(x)

# %%
x.info()

# %%
class Student:

    def __init__(self):
        print("hello world")

# %%
s1 = Student()
# Out:
# hello world

# %%
class PasswordGenerator:
    import random

    def __init__(self):
        self.length = 8
        self.characters = "abcdefjhijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"

    def generate_passcode(self, length):
        chars = "abcdefjhijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1234567890!@#$%^&*"
        password = ""
        for _ in range(self.length):
            password += random.choice(chars)
        return password


if __name__ == "__main__":
    generator = PasswordGenerator()
    random_password = generator.generate_passcode(8)
    print(random_password)
# Out:
# vbpIZcTS
